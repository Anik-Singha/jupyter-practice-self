# %% [markdown]
# # DATA TYPES

# %%
type(12)
# Out:
# int

# %%
type(2+0.1)
# Out:
# float

# %%
type(2+7j)
# Out:
# complex

# %%
type(False)
# Out:
# bool

# %%
type('abc')
# Out:
# str

# %%
type([1,2,3])
# Out:
# list

# %%
type((1,2,3))
# Out:
# tuple

# %%
type({1,2,3})
# Out:
# set

# %%
type({1:'a',2:'b',3:'c'})
# Out:
# dict
