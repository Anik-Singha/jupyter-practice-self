# %% [markdown]
# ## If - Elif - Else Statements

# %%
if 30 > 10 :
    print("It worked")
# Out:
# It worked

# %%
if 10 > 50:
    print("It worked")
else: print("It didnt work")
# Out:
# It didnt work

# %%
if 10 > 50:
    print("It worked")
elif 30 > 10:
    print("It worked 2nd")
else: print("It didnt work")
# Out:
# It worked 2nd
